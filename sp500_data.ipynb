# %%
import pandas as pd
import yfinance as yf

# %%
import pandas as pd
fedex_wiki_url="https://en.wikipedia.org/wiki/FedEx"
fedex_wiki_df_list=pd.read_html(fedex_wiki_url)
fedex_wiki_df_list
# Out:
# [                                                0  \
#  0                                             NaN
#  1   FedEx Services headquarters in New York City.
#  2                                      Trade name
#  3                                        Formerly
#  4                                            Type
#  5                                       Traded as
#  6                                            ISIN
#  7                                        Industry
#  8                                         Founded
#  9                                         Founder
#  10                                   Headquarters
#  11                            Number of locations
#  12                                    Area served
#  13                                     Key people
#  14                                       Products
#  15                                       Services
#  16                                        Revenue
# ...

# %%
fedex=fedex_wiki_df_list[1]

# %%
fedex.to_csv('/Users/kaharbawa/Documents/Data_Scraping/fedex.csv', index=False)

# %%
sp_wiki_url="https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
sp_wiki_df_list=pd.read_html(sp_wiki_url)
sp_wiki_df_list
# Out:
# [    Symbol             Security SEC filings             GICS Sector  \
#  0      MMM                   3M     reports             Industrials
#  1      ABT  Abbott Laboratories     reports             Health Care
#  2     ABBV               AbbVie     reports             Health Care
#  3     ABMD              Abiomed     reports             Health Care
#  4      ACN            Accenture     reports  Information Technology
#  ..     ...                  ...         ...                     ...
#  500    YUM          Yum! Brands     reports  Consumer Discretionary
#  501   ZBRA   Zebra Technologies     reports  Information Technology
#  502    ZBH        Zimmer Biomet     reports             Health Care
#  503   ZION        Zions Bancorp     reports              Financials
#  504    ZTS               Zoetis     reports             Health Care
#
#                        GICS Sub-Industry    Headquarters Location  \
#  0              Industrial Conglomerates    Saint Paul, Minnesota
# ...

# %%
sp_df=sp_wiki_df_list[0]
sp_ticker_lst=list(sp_df['Symbol'].values)
sp_ticker_lst
# Out:
# ['MMM',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADBE',
#  'AMD',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BLL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
# ...

# %%
df=yf.download(sp_ticker_lst)
# Out:
# [*********************100%***********************]  505 of 505 completed
#
# 2 Failed downloads:
# - BF.B: No data found for this date range, symbol may be delisted
# - BRK.B: No data found, symbol may be delisted

# %%
Adj_close=df['Adj Close']
Adj_close=Adj_close.reset_index("Date")
Adj_close.head()
# Out:
#         Date   A  AAL  AAP  AAPL  ABBV  ABC  ABMD  ABT  ACN  ...  XEL  XLNX  \
# 0 1962-01-02 NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN  NaN  ...  NaN   NaN
# 1 1962-01-03 NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN  NaN  ...  NaN   NaN
# 2 1962-01-04 NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN  NaN  ...  NaN   NaN
# 3 1962-01-05 NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN  NaN  ...  NaN   NaN
# 4 1962-01-08 NaN  NaN  NaN   NaN   NaN  NaN   NaN  NaN  NaN  ...  NaN   NaN
#
#         XOM  XRAY  XYL  YUM  ZBH  ZBRA  ZION  ZTS
# 0  0.101906   NaN  NaN  NaN  NaN   NaN   NaN  NaN
# 1  0.103420   NaN  NaN  NaN  NaN   NaN   NaN  NaN
# 2  0.103672   NaN  NaN  NaN  NaN   NaN   NaN  NaN
# 3  0.101402   NaN  NaN  NaN  NaN   NaN   NaN  NaN
# 4  0.101150   NaN  NaN  NaN  NaN   NaN   NaN  NaN
#
# [5 rows x 506 columns]

# %%
All_sp500=Adj_close.loc[12089:15117,]

# %%
All_sp500.to_csv('/Users/kaharbawa/Documents/AllSP500.csv', index=False, encoding='utf-8')

# %%
sp_500=Adj_close.loc[12089:15117,["Date", "NVR","AMZN", "GOOG","GOOGL" ,"BKNG" , "AZO" ,"CMG","MTD","TSLA","BLK", "NFLX", "DXCM", "NVDA", "ABMD", "URI", "DPZ","ALGN","AVGO","AMD","FTNT", "VZ","PEP", "XEL" ,"DUK", "SO" , "PEG", "CMS", "PG",  "ED",  "AEP"]]

# %%
sp.head()
# Out:
#         Date   A  AAL
# 0 1962-01-02 NaN  NaN
# 1 1962-01-03 NaN  NaN
# 2 1962-01-04 NaN  NaN
# 3 1962-01-05 NaN  NaN
# 4 1962-01-08 NaN  NaN

# %%
sp_500.to_csv('/Users/kaharbawa/Documents/Fiverr.csv', index=False)
