# %%
import os
os.chdir("/Users/kaharbawa/Documents/My_Publishing ")

# %%
os.getcwd()
# Out:
# '/Users/kaharbawa/Documents/My_Publishing '

# %% [markdown]
# # 1. Multiple Folder Creation

# %%
import pathlib

# %%
from pathlib import Path
import calendar

month_names = list(calendar.month_name[1:])
days = ['Day 1', 'Day 8', 'Day 15', 'Day 22', 'Day 28']

for i, month in enumerate(month_names):
    for day in days:
        Path(f'2022/{i+1}.{month}/{day}').mkdir(parents=True, exist_ok=True)

# %%
month_names
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December']

# %% [markdown]
# # 2. Extract Tables from PDFs

# %%
import camelot
tables=camelot.read_pdf('foo.pdf', pages='1', flavor='lattice')
print(tables)

# %%
tables.export('foo.csv', f='csv', compress='True')

# %%
tables[0].to_csv('foo.csv')  # to a csv file
print(tables[0].df)  # to a df

# %% [markdown]
# # 3. Extract Tables from Websites

# %%
import pandas as pd
simpsons=pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)')

# %%
simpsons[17]
# Out:
#     No.overall  No. inseason                                 Title  \
# 0          357             1         "The Bonfire of the Manatees"
# 1          358             2       "The Girl Who Slept Too Little"
# 2          359             3            "Milhouse of Sand and Fog"
# 3          360             4             "Treehouse of Horror XVI"
# 4          361             5               "Marge's Son Poisoning"
# 5          362             6                       "See Homer Run"
# 6          363             7       "The Last of the Red Hat Mamas"
# 7          364             8                     "The Italian Bob"
# 8          365             9          "Simpsons Christmas Stories"
# 9          366            10              "Homer's Paternity Coot"
# 10         367            11      "We're on the Road to D'ohwhere"
# 11         368            12                       "My Fair Laddy"
# 12         369            13    "The Seemingly Never-Ending Story"
# 13         370            14                "Bart Has Two Mommies"
# 14         371            15    "Homer Simpson, This Is Your Wife"
# 15         372            16                 "Million Dollar Abie"
# 16         373            17           "Kiss Kiss, Bang Bangalore"
# 17         374            18       "The Wettest Stories Ever Told"
# 18         375            19        "Girls Just Want to Have Sums"
# 19         376            20                    "Regarding Margie"
# 20         377            21                     "The Monkey Suit"
# 21         378            22  "Marge and Homer Turn a Couple Play"
#
#           Directed by                      Written by   Original air date  \
# 0       Mark Kirkland                     Dan Greaney  September 11, 2005
# 1    Raymond S. Persi                      John Frink  September 18, 2005
# 2   Steven Dean Moore               Patric M. Verrone  September 25, 2005
# 3     David Silverman                    Marc Wilmore    November 6, 2005
# 4    Mike B. Anderson                     Daniel Chun   November 13, 2005
# 5         Nancy Kruse                Stephanie Gillis   November 20, 2005
# 6      Matthew Nastuk                   Joel H. Cohen   November 27, 2005
# 7       Mark Kirkland                      John Frink   December 11, 2005
# 8   Steven Dean Moore                       Don Payne   December 18, 2005
# 9    Mike B. Anderson                   Joel H. Cohen     January 8, 2006
# 10        Nancy Kruse                    Kevin Curran    January 29, 2006
# 11       Bob Anderson                   Michael Price   February 26, 2006
# 12   Raymond S. Persi              Ian Maxtone-Graham      March 12, 2006
# 13     Mike Marcantel                      Dana Gould      March 19, 2006
# 14     Matthew Nastuk                   Ricky Gervais      March 26, 2006
# 15  Steven Dean Moore                        Tim Long       April 2, 2006
# 16      Mark Kirkland  Deb Lacusta & Dan Castellaneta       April 9, 2006
# 17   Mike B. Anderson                  Jeff Westbrook      April 23, 2006
# 18        Nancy Kruse                     Matt Selman      April 30, 2006
# 19    Michael Polcino                    Marc Wilmore         May 7, 2006
# 20   Raymond S. Persi                J. Stewart Burns        May 14, 2006
# 21       Bob Anderson                   Joel H. Cohen        May 21, 2006
#
#    Prod.code U.S. viewers(millions)
# 0     GABF18             11.10[305]
# 1     GABF16              9.79[306]
# 2     GABF19             10.19[307]
# 3     GABF17             11.63[308]
# 4     GABF20              11.4[309]
# 5     GABF21              10.3[310]
# 6     GABF22             11.46[311]
# 7     HABF02             10.39[312]
# 8     HABF01               9.8[313]
# 9     HABF03              10.1[314]
# 10    HABF04              9.04[315]
# 11    HABF05              9.51[316]
# 12    HABF06              9.72[317]
# 13    HABF07              8.75[318]
# 14    HABF08             10.09[319]
# 15    HABF09              7.83[320]
# 16    HABF10              8.20[321]
# 17    HABF11              7.04[322]
# 18    HABF12               8.7[323]
# 19    HABF13              8.50[324]
# 20    HABF14               8.3[325]
# 21    HABF16              8.23[326]

# %% [markdown]
# # 4. Sending Messages on WhatsApp

# %%
import pywhatkit
# syntax: phone number with country code, message, hour and minutes
pywhatkit.sendwhatmsg('+22960680507', 'Hi! this is bawa reaching out about an amazing deal', 20, 25)
# Out:
# In 332 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!
